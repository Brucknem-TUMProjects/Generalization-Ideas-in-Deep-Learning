# %%
import data_loader
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
subset_size = 50001
train = data_loader.get_CIFAR10_dataloader(True, subset_size=subset_size)
test = data_loader.get_CIFAR10_dataloader(False, subset_size=subset_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(vars(train))
print(len((train)))
# Out:
# {'dataset': Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            ), 'num_workers': 8, 'pin_memory': False, 'timeout': 0, 'worker_init_fn': None, '_DataLoader__multiprocessing_context': None, '_dataset_kind': 0, 'batch_size': 64, 'drop_last': False, 'sampler': <torch.utils.data.sampler.SubsetRandomSampler object at 0x7fdfc6fa95f8>, 'batch_sampler': <torch.utils.data.sampler.BatchSampler object at 0x7fdfc717dc18>, 'collate_fn': <function default_collate at 0x7fdfc8a01510>, '_DataLoader__initialized': True}
# 625

# %%
trainset = data_loader.load_CIFAR10_dataset(True)
# Out:
# Files already downloaded and verified

# %%
print(trainset)
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
import random
random.sample(range(0, len(trainset)), min(100000, len(trainset)))
# Out:
# [19413,
#  47411,
#  554,
#  17486,
#  36988,
#  3405,
#  36151,
#  44046,
#  8127,
#  33222,
#  1335,
#  20983,
#  25195,
#  26111,
#  12263,
#  39909,
#  14684,
#  46285,
#  21628,
#  28902,
#  2587,
#  4547,
#  10316,
#  31951,
#  19690,
#  6822,
#  9684,
#  46381,
#  46339,
#  20776,
#  25207,
#  46072,
#  7155,
#  34566,
#  17234,
#  18806,
#  569,
#  31715,
#  30987,
#  41844,
#  17137,
#  9343,
#  37487,
#  5559,
#  32314,
#  15101,
#  15976,
#  1288,
#  24110,
#  24712,
#  32148,
#  37987,
#  3687,
#  49273,
#  48269,
#  4315,
#  18114,
#  2874,
#  41042,
#  46832,
#  28673,
#  48690,
#  34862,
#  11592,
#  10430,
#  30728,
#  15962,
#  44489,
#  10375,
#  40604,
#  28704,
#  28307,
#  21740,
#  33356,
#  10918,
#  1133,
#  47398,
#  40485,
#  25880,
#  45611,
#  49086,
#  44066,
#  34711,
#  40678,
#  31518,
#  39849,
#  25603,
#  14182,
#  35068,
#  9873,
#  4302,
#  5501,
#  10849,
#  30285,
#  12460,
#  19011,
#  43854,
#  13663,
#  19197,
#  17866,
#  25130,
#  33052,
# ...
