# %%
import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pprint import pprint

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
from networks import ExampleNet, vgg11
from solver import Solver, load_solver
import data_visualization
import data_loader

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
best_solver = load_solver()
best_solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1381">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1382">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="14955e20-dab1-4ad6-8487-753fb7ee9470" data-root-id="1467"></div>
#   <div class="bk-root" id="fddfb721-f36a-40de-889d-7a91870142e2" data-root-id="1607"></div>

# %%
best_solver.print_log()
# Out:
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    1,        15]    2.28652309 |        0.11666667
# ----------------------------------------------------
# [    1,  finished]     accuracy: |        0.13200000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    2,        15]    2.18052492 |        0.20104167
# ----------------------------------------------------
# [    2,  finished]     accuracy: |        0.20500000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    3,        15]    2.06806176 |        0.26250000
# ----------------------------------------------------
# [    3,  finished]     accuracy: |        0.27200000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    4,        15]    1.97766472 |        0.29895833
# ----------------------------------------------------
# [    4,  finished]     accuracy: |        0.25300000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    5,        15]    1.92320148 |        0.30312500
# ----------------------------------------------------
# [    5,  finished]     accuracy: |        0.27600000
