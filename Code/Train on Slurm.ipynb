# %%
import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pprint import pprint

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
from networks import ExampleNet, vgg11, extract_layer_names
from solver import Solver, load_solver
import data_visualization
import data_loader

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
best_solver = load_solver()
best_solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3ba66860-c17d-4a89-975a-d8a505eebd10" data-root-id="1087"></div>
#   <div class="bk-root" id="28974478-931e-4b54-8da2-b185d9e268c5" data-root-id="1201"></div>

# %%
best_solver.print_log()
# Out:
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    1,         4]    2.30504119 |        0.11718750
# [    1,         8]    2.29238433 |        0.13671875
# [    1,        12]    2.28302062 |        0.13671875
# [    1,        16]    2.25247830 |        0.20078125
# ----------------------------------------------------
# [    1,  finished]     accuracy: |        0.19200000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    2,         4]    2.20731193 |        0.16796875
# [    2,         8]    2.22635710 |        0.16015625
# [    2,        12]    2.15363437 |        0.16796875
# [    2,        16]    2.15714949 |        0.21171875
# ----------------------------------------------------
# [    2,  finished]     accuracy: |        0.19500000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    3,         4]    2.12737077 |        0.23828125
# [    3,         8]    2.05556709 |        0.21875000
# [    3,        12]    2.11904567 |        0.18750000
# [    3,        16]    2.07619631 |        0.22109375
# ----------------------------------------------------
# [    3,  finished]     accuracy: |        0.23000000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    4,         4]    1.99979123 |        0.23437500
# [    4,         8]    1.99835438 |        0.21484375
# [    4,        12]    2.02244243 |        0.20312500
# [    4,        16]    2.03126296 |        0.29609375
# ----------------------------------------------------
# [    4,  finished]     accuracy: |        0.23800000
#
# [epoch, iteration] training loss | training accuracy
# ----------------------------------------------------
# [    5,         4]    1.97238228 |        0.27734375
# [    5,         8]    1.90908056 |        0.21875000
# [    5,        12]    1.88844663 |        0.29687500
# [    5,        16]    1.89529008 |        0.30234375
# ----------------------------------------------------
# [    5,  finished]     accuracy: |        0.29800000
