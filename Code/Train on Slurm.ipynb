# %%
import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pprint import pprint

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
from networks import ExampleNet, vgg11
from solver import Solver, load_solver
import data_visualization
import data_loader

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#solver = load_solver(folder='../brucknem/vgg16_bn_40000_labels/', filename='solver_e_reached_100.pth', verbose=False)
solver = load_solver(folder='../brucknem/vgg16_bn_confusion_1000', filename='solver_e_reached_100.pth', verbose=False)
solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1381">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1382">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a0df1cf5-61d6-4e8d-9b3c-c406516a5212" data-root-id="1467"></div>
#   <div class="bk-root" id="2c435df6-c46e-4431-9a30-1e04cc2a5655" data-root-id="1607"></div>

# %%
#solver = load_solver(folder='../brucknem/vgg16_bn_40000_labels/', filename='solver_e_reached_100.pth', verbose=False)
solver = load_solver(folder='../brucknem/vgg16_bn_confusion_2000', filename='solver_e1050.pth', verbose=False)
solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2833">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2834">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="22811006-1039-48e5-9b5e-35ffb84eccb9" data-root-id="2919"></div>
#   <div class="bk-root" id="eb449429-89cd-452f-bc39-dde78332064c" data-root-id="3137"></div>

# %%
#solver = load_solver(folder='../brucknem/vgg16_bn_40000_labels/', filename='solver_e_reached_100.pth', verbose=False)
solver = load_solver(folder='../brucknem/vgg16_bn_confusion_3000', filename='solver_e_reached_100.pth', verbose=False)
solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1813">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1814">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="70783ef9-fa37-49b9-91fe-a120498b7cab" data-root-id="1899"></div>
#   <div class="bk-root" id="39b9b1e5-531d-48eb-8419-87f00b0e7eef" data-root-id="2065"></div>

# %%
#solver = load_solver(folder='../brucknem/vgg16_bn_40000_labels/', filename='solver_e_reached_100.pth', verbose=False)
solver = load_solver(folder='../brucknem/vgg16_bn_confusion_4000', filename='solver_e_reached_100.pth', verbose=False)
solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2297">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2298">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="dcde17f5-9236-42f0-b955-db05064a3ac0" data-root-id="2383"></div>
#   <div class="bk-root" id="f2cc6066-c73d-42cf-8838-4a03940c652d" data-root-id="2575"></div>

# %%
#solver = load_solver(folder='../brucknem/vgg16_bn_40000_labels/', filename='solver_e_reached_100.pth', verbose=False)
solver = load_solver(folder='../brucknem/vgg16_bn_confusion_5000', filename='solver_e900.pth', verbose=False)
solver.print_bokeh_plots()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3421">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3422">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="331a25f7-9185-4ead-b476-c77f26445de2" data-root-id="3507"></div>
#   <div class="bk-root" id="3b05666e-03aa-4cf8-9e5f-1b16e316a964" data-root-id="3751"></div>
