# %%
from solver import Solver, load_solver, save_solver
from pprint import pprint
import norms

# %%
latest = load_solver(filename="solver.pth", folder='solvers')
print(norms.l2_norm_product(latest.model.state_dict()))
latest.print_bokeh_plots()
pprint(vars(latest))
# Out:
# 430.2046137144291
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="515318bb-f0da-4512-a4cf-b991ecdbc625" data-root-id="1087"></div>
#   <div class="bk-root" id="2e368197-fc01-4d5c-a102-f3011477c19e" data-root-id="1201"></div>
# {'best_params': None,
#  'best_solver': <solver.Solver object at 0x7f7c194d2518>,
#  'best_val_acc': 0.5987,
#  'criterion': 'cross_entropy_loss',
#  'criterion_func': <function cross_entropy_loss at 0x7f7c21954840>,
#  'device': device(type='cuda', index=0),
#  'log_buffer': '[epoch, iteration] training loss | training accuracy\n'
# ...

# %%
best = load_solver(filename="solver_best.pth", folder='solvers')
print(norms.l2_norm_product(best.model.state_dict()))
best.print_bokeh_plots()
pprint(vars(best))
# Out:
# 430.2046137144291
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1381">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1382">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f4ec3589-9084-45da-b3fc-26a545b84361" data-root-id="1467"></div>
#   <div class="bk-root" id="949fbf2a-eda4-43ce-a097-a0446f91dd27" data-root-id="1607"></div>
# {'best_params': None,
#  'best_solver': None,
#  'best_val_acc': 0.5987,
#  'criterion': 'cross_entropy_loss',
#  'criterion_func': <function cross_entropy_loss at 0x7f7c21954840>,
#  'device': device(type='cuda', index=0),
#  'log_buffer': '[epoch, iteration] training loss | training accuracy\n'
#                '----------------------------------------------------\n'
# ...

# %%
e2 = load_solver(filename="solver_e2.pth", folder='solvers')
print(norms.l2_norm_product(e2.model.state_dict()))
e2.print_bokeh_plots()
pprint(vars(e2))
# Out:
# 51.69855789406598
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1813">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1814">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4a373eb8-3e55-4f57-b83f-3bb45ad16482" data-root-id="1899"></div>
#   <div class="bk-root" id="b23d9471-8d28-4b05-943e-e41f44fb12eb" data-root-id="2065"></div>
# {'best_params': None,
#  'best_solver': <solver.Solver object at 0x7f7c194d2550>,
#  'best_val_acc': 0.5217,
#  'criterion': 'cross_entropy_loss',
#  'criterion_func': <function cross_entropy_loss at 0x7f7c21954840>,
#  'device': device(type='cuda', index=0),
#  'log_buffer': '[epoch, iteration] training loss | training accuracy\n'
# ...

# %%
e4 = load_solver(filename="solver_e4.pth", folder='solvers')
print(norms.l2_norm_product(e4.model.state_dict()))
e4.print_bokeh_plots()
pprint(vars(e4))
# Out:
# 225.9055218119626
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2297">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2298">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="57263950-a663-4486-b82a-63fff86e3119" data-root-id="2383"></div>
#   <div class="bk-root" id="9ca5a5da-e05a-4b18-84c2-57eb0bd62ec9" data-root-id="2575"></div>
# {'best_params': None,
#  'best_solver': <solver.Solver object at 0x7f7c168cf1d0>,
#  'best_val_acc': 0.5764,
#  'criterion': 'cross_entropy_loss',
#  'criterion_func': <function cross_entropy_loss at 0x7f7c21954840>,
#  'device': device(type='cuda', index=0),
#  'log_buffer': '[epoch, iteration] training loss | training accuracy\n'
# ...
