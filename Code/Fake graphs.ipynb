# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, output_file, export_png
from pprint import pprint
from bokeh.models import Range1d
from bokeh.models import NumeralTickFormatter

# %%
x = [10000, 20000, 30000, 40000, 50000]
# l2_path_measures = ['L2-path norm', x, [],[], (,)]
# spectral_measures = ['Spectral norm', x, [],[], (,)]
# sharpness_measures = ['Sharpness', x, [],[], (,)]

# %%
def plot(title, x_labels, y_true, y_random, y_range,  x_axis_label='Size of training set', legend_location = 'top_left'):
    p = figure(title = title, x_axis_label=x_axis_label, y_range=Range1d(*y_range), y_axis_type="log",
          width=int(800*.7), height=int(600*.7))
    p.line(x_labels, y_true, legend_label='true labels', line_width=2)
    p.square(x_labels, y_true, legend_label='true labels', line_width=4)
    p.line(x_labels, y_random, legend_label='random labels', line_color='magenta', line_width=2)
    p.circle(x_labels, y_random, legend_label='random labels', line_color='magenta', fill_color='magenta', line_width=4)
    p.xaxis.formatter=NumeralTickFormatter(format="0a")
    p.title.text_font_size = '16pt'
    p.xaxis.axis_label_text_font_size = '16pt'
    p.xaxis.major_label_text_font_size = '16pt'
    p.yaxis.axis_label_text_font_size = '16pt'
    p.yaxis.major_label_text_font_size = '16pt'
    p.legend.location = legend_location
    output_notebook()
    show(p)
#     output_file('/mnt/nextcloud/tum/Master/3.Semester/Seminar/Presentation/vgg16_random_labels/' + title.replace(' ', ''))
#     show(p)
#     export_png(p, '/mnt/nextcloud/tum/Master/3.Semester/Seminar/Presentation/vgg16_random_labels/' + title.replace(' ', '') + '.png')

# %%
l2_measures = ['L2 norm', x, [1e21, 2e21, 3e21, 4e21, 5e21],[1e22, 1e23, 1e24, 1e25, 1.2e25], (1e20, 1e30)]
plot(*l2_measures)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1096">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="33083c88-a878-488d-a559-36470a4b37f8" data-root-id="1002"></div>

# %%
l1_path_measures = ['L1-path norm', x, [5e26, 1.3e27, 3e27, 6.5e27, 10e27],[5e27, 4e28, 3e29, 1e30, 0.95e30], (1e25, 1e35)]
plot(*l1_path_measures)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1283">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6ab15c7b-7923-48fa-8635-10ca29dd6426" data-root-id="1189"></div>

# %%
l2_path_measures = ['L2-path norm', x, [2e0, 4e0, 6e0, 8e0, 1e1],[1e1, 2.2e2, 3e3, 9e3, 9e3], (1e0, 1e4)]
plot(*l2_path_measures)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1483">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2211dee2-f39e-4f55-86b1-8a937ec473a2" data-root-id="1389"></div>

# %%
spectral_measures = ['Spectral norm', x, [1e7, 6e7, 3e8, 8e8, 1e9],[1e9, 5e10, 8e11, 3e12, 4e12], (1e5, 1e15)]
plot(*spectral_measures)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1696">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f61ab9f9-0252-423b-bdde-207d6279f279" data-root-id="1602"></div>
